# %%
#It is necessary to import pandas and the animate_trajectory function

import pandas as pd
from functions import animate_trajectory

# %%
#To generate a gif from a file, open the file with pandas

trajectory = pd.read_csv('simulationdata/vicseksimulation,N=10,L=1,v=0.01,T=100,R=0.05,sigma=1')

# %%
#Note that in the name of the file there's the parameters L,v,R and sigma
#This parameter is necessary to run animate_trajectory

L=1
v=0.01
R=0.05
sigma=1

#Generating the gif:

animate_trajectory(trajectory,L)

#The gif will be at simulationgifs/ folder
